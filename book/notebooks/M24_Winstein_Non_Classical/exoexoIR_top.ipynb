# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np

# %%
file = 'endoexoIR_endo_top.csv'
#file = 'exoexoIR_top.csv'
df = pd.read_csv(file, names=['A','B']
                 )

df.sort_values(by='A', inplace=True)
x = df['A']
y = df['B']

x = 1/x *1E6 /100
plt.plot(x,y)
#plt.xlim(3000,800)


file = 'exoexoIR_top.csv'
df = pd.read_csv(file, names=['A','B']
                 )

df.sort_values(by='A', inplace=True)
x = df['A']
y = df['B']

x = 1/x *1E6 /100
plt.plot(x,y)
plt.xlim(1600,450)
#plt.xticks([4000,2200,1000,450])
plt.savefig("plot.pdf")

# %%
x.head()
# Out:
# 0    2941.119427
# 1    2913.181954
# 2    2896.672788
# 3    2896.672788
# 4    2885.770240
# Name: A, dtype: float64

# %%
1/(5/1E6)/100
# Out:
# 1999.9999999999998
