# %%
import pandas as pd

# UV vis spectra of benzyl alcohol
# Data from "Quest Graph™ Absorption [Benzyl Alcohol]." AAT Bioquest, Inc., 28 Oct. 2025, https://www.aatbio.com/absorbance-uv-visible-spectrum-graph-viewer/benzyl_alcohol.
# [Wavelength (nm), normalized abs (%)]

dataBnOH = [[229,7],[229,7],[229,7],[229,7],[229,7],[229,7],[230,7],
        [230,7],[230,7],[230,7],[230,7],[230,7],[230,7],[231,8],[231,8],
        [231,8],[231,9],[232,9],[232,9],[232,9],[232,9],[232,9],[232,9],
        [233,10],[233,10],[233,10],[233,11],[233,11],[233,11],[235,14],
        [236,17],[236,17],[236,18],[236,18],[237,18],[237,19],[237,19],
        [237,20],[237,19],[238,21],[239,23],[239,24],[240,25],[240,26],
        [240,26],[240,27],[240,27],[241,28],[241,29],[241,30],[241,30],
        [241,31],[241,32],[241,32],[242,33],[242,34],[242,34],[242,35],
        [242,35],[242,36],[242,36],[243,37],[243,37],[245,41],[245,42],
        [245,43],[245,43],[245,44],[245,45],[246,45],[246,46],[246,47],
        [246,48],[246,49],[246,49],[246,50],[247,51],[247,52],[247,53],
        [247,53],[247,54],[247,55],[248,56],[248,57],[249,57],[250,59],
        [250,59],[250,60],[250,61],[250,62],[251,62],[251,63],[251,65],
        [251,67],[251,69],[251,71],[251,73],[252,74],[252,76],[252,77],
        [252,78],[252,79],[252,80],[253,81],[253,81],[253,80],[254,81],
        [254,80],[254,79],[254,78],[254,78],[254,77],[255,76],[255,75],
        [256,76],[256,77],[256,77],[257,78],[257,80],[257,82],[257,84],
        [257,86],[257,88],[258,90],[258,93],[258,95],[258,98],[258,99],
        [258,99],[259,100],[259,100],[259,100],[259,99],[259,98],[260,96],
        [260,94],[260,92],[260,89],[260,88],[260,86],[261,84],[261,83],
        [261,82],[261,81],[261,80],[261,80],[262,79],[262,78],[262,78],
        [262,77],[262,76],[262,74],[263,72],[263,70],[263,69],[263,68],
        [263,67],[264,67],[264,69],[264,71],[264,73],[264,74],[264,76],
        [265,77],[265,77],[265,77],[265,77],[265,74],[265,71],[266,70],
        [266,66],[266,63],[266,60],[266,57],[267,55],[267,52],[267,50],
        [267,48],[267,47],[267,46],[268,46],[268,45],[268,45],[269,45],
        [269,45],[269,45],[269,42],[270,38],[270,28],[270,27],[270,27],
        [270,26],[271,23],[271,22],[271,19],[271,17],[271,15],[271,14],
        [272,12],[272,11],[272,10],[272,9],[272,8],[273,8],[273,7],[273,7],
        [273,6],[273,6],[274,6],[274,5],[274,4],[274,4],[274,3],[274,3],
        [275,3],[275,2],[275,2]]

df_BnOH = pd.DataFrame(dataBnOH, columns=['Wavelength (nm)', 'Normalized Abs (%)']) 

# bin according to wavelength values and average absorbances within each bin
df_BnOH_binned = df_BnOH.groupby('Wavelength (nm)', as_index=False).mean()
df_BnOH_binned['Normalized Abs (%)'] = df_BnOH_binned['Normalized Abs (%)']

dataBnOH = pd.read_csv('BnOHspectra.csv')
dataBnOH
# Out:
#      Wavelength  Normalized Abs (%)
# 0    228.714199            6.770834
# 1    228.846149            6.770834
# 2    228.978251            6.770834
# 3    229.110506            6.770834
# 4    229.242914            6.770834
# ..          ...                 ...
# 212  274.256778            3.125000
# 213  274.446455            2.864583
# 214  274.636471            2.604167
# 215  274.826825            2.343750
# 216  275.017367            2.083333
#
# [217 rows x 2 columns]

# %%
import pandas as pd

# UV vis spectra of benzyl chloride
# Data from https://webbook.nist.gov/cgi/cbook.cgi?ID=C100447
# [Wavelength (nm), log_e]

dataBnCl = [[210,2.75],[211,2.75],[212,2.75],[213,2.75],[214,2.75],[215,2.75],
            [216,2.75],[217,2.78],[218,2.78],[219,2.98],[220,3.14],[221,3.26],
            [222,3.35],[223,3.43],[224,3.48],[225,3.48],[226,3.47],[227,3.39],
            [228,3.35],[229,3.30],[230,3.25],[231,3.20],[232,3.13],[233,3.05],
            [234,2.96],[235,2.85],[236,2.69],[237,2.43],[238,2.39],[239,2.32],
            [240,2.27],[241,2.32],[242,2.27],[243,2.36],[244,2.52],[245,2.53],
            [246,2.54],[247,2.56],[248,2.57],[249,2.58],[250,2.60],[251,2.61],
            [252,2.62],[253,2.63],[254,2.64],[255,2.65],[256,2.66],[257,2.67],
            [258,2.69],[259,2.69],[260,2.70],[261,2.71],[262,2.72],[263,2.72],
            [264,2.72],[265,2.72],[266,2.71],[267,2.71],[268,2.71],[269,2.71],
            [270,2.71],[271,2.70],[272,2.70],[273,2.70],[274,2.70],[275,2.70],
            [276,2.69],[277,2.69],[278,2.69],[279,2.69],[280,2.69],[281,2.68],
            [282,2.68],[283,2.68],[284,2.68],[285,2.67],[286,2.67],[287,2.67],
            [288,2.67],[289,2.67]]

df_BnCl = pd.DataFrame(dataBnCl, columns=['Wavelength (nm)', 'log_e'])
df_BnCl['e'] = df_BnCl['log_e'].apply(lambda x: 10**x)
df_BnCl['Normalized Abs (%)'] = df_BnCl['e']/df_BnCl['e'].max() * 100
df_BnCl.max()
# Out:
# Wavelength (nm)        289.00000
# log_e                    3.48000
# e                     3019.95172
# Normalized Abs (%)     100.00000
# dtype: float64

# %%
import matplotlib.pyplot as plt

fig,ax = plt.subplots(figsize=(5,4))

x = df_BnOH_binned['Wavelength (nm)']
y = df_BnOH_binned['Normalized Abs (%)']
ax.plot(x, y, color='blue')

x = df_BnCl['Wavelength (nm)']
y = df_BnCl['Normalized Abs (%)']   
ax.plot(x, y, color='red')

ax.set_xlabel('Wavelength (nm)')
ax.set_ylabel('Normalized Abs (%)')

plt.show()
