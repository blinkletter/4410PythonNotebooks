# %%
import numpy as np
import pandas as pd

import uncertainties as un
import uncertainties.unumpy as unp


df = pd.read_csv('TaftData1952.csv',
                 delimiter = ",", 
                 skipinitialspace=True, 
                 index_col="Sub", 
                 comment = "#")

# %%
n = df['base ratio']
e = df['base error']

p = unp.uarray(n, e)  # Create an array of uncertainties

#a = 10**p * 43E-6  # Convert to an array of values with uncertainties
a = 10**p * 0.112  # Convert to an array of values with uncertainties

unp.log10(a/a[1])
# Out:
# array([2.46+/-0.14422205101855953, 0.0+/-8.881784197001253e-18,
#        -0.31+/-0.09433981132056603, -0.64+/-0.12041594578792295,
#        -0.71+/-0.12041594578792295, -0.55+/-0.08246211251235322,
#        nan+/-nan, 0.17+/-0.08544003745317533,
#        -0.13999999999999996+/-0.08062257748298549,
#        -0.4000000000000001+/-0.08246211251235322,
#        -0.94+/-0.1131370849898476, nan+/-nan, -1.24+/-0.09999999999999999,
#        -1.13+/-nan, nan+/-nan, -0.93+/-nan, -1.42+/-nan,
#        -2.38+/-0.14422205101855956, -1.09+/-nan,
#        -2.7+/-0.09999999999999999, -0.75+/-0.12041594578792295, nan+/-nan,
#        -1.06+/-0.08944271909999159, nan+/-nan], dtype=object)

# %%
for i in a:
#    print(f"{i.n:.3e} ± {unp.std_devs(i):.3e}")
    print(f"{i:.3e}")
# Out:
# (3.230+/-0.893)e+01
# (1.120+/-0.206)e-01
# (5.486+/-0.632)e-02
# (2.566+/-0.532)e-02
# (2.184+/-0.453)e-02
# (3.157+/-0.145)e-02
# nan+/-nan
# (1.657+/-0.114)e-01
# (8.114+/-0.187)e-02
# (4.459+/-0.205)e-02
# (1.286+/-0.237)e-02
# nan+/-nan
# (6.445+/-0.890)e-03
# (8.303+/-nan)e-03
# nan+/-nan
# (1.316+/-nan)e-02
# (4.258+/-nan)e-03
# (4.669+/-1.290)e-04
# (9.104+/-nan)e-03
# (2.235+/-0.309)e-04
# (1.992+/-0.413)e-02
# nan+/-nan
# (9.755+/-0.898)e-03
# nan+/-nan

# %%
df
# Out:
#                acid ratio  acid Error  base ratio  base error
# Sub
# H                    1.24        0.09        2.46        0.12
# CH3                  0.00        0.06        0.00        0.08
# C2H5                -0.07        0.02       -0.31        0.05
# n-C3H7              -0.36        0.02       -0.64        0.09
# n-C4H9              -0.39        0.05       -0.71        0.09
# n-C5H11             -0.40        0.07       -0.55        0.02
# i-C5H11             -0.35        0.01         NaN         NaN
# CH2C6C5             -0.38        0.04        0.17        0.03
# CH2CH2C6H5          -0.43        0.09       -0.14        0.01
# CH2CH2CH2C6H5       -0.45        0.06       -0.40        0.02
# i-C3H7              -0.47        0.06       -0.94        0.08
# c-C6H11             -0.79        0.17         NaN         NaN
# i-C4H9              -0.93        0.10       -1.24        0.06
# CH2-c-C6H11         -0.98        0.05       -1.13         NaN
# ...

# %%
import numpy as np
import pandas as pd

import uncertainties as un
import uncertainties.unumpy as unp


df = pd.read_csv('TaftData1952rates.csv',
                 delimiter = ",", 
                 skipinitialspace=True, 
                 index_col="Substituent", 
                 comment = "#") 

df
# Out:
#                           Group  acid rate (s-1)      acid err  \
# Substituent
# H                             H     7.473000e-04  1.549000e-04
# CH3                          Me     4.300000e-05  5.941000e-06
# CH2Cl                     CH2Cl     2.776000e-05  3.196000e-06
# C2H5                         Et     3.660000e-05  1.685000e-06
# CH2CH2CH3                  n-Pr     1.877000e-05  8.644000e-07
# (CH2)3CH3                  n-Bu     1.752000e-05  2.017000e-06
# (CH2)4CH3              n-pentyl     1.712000e-05  2.759000e-06
# (CH2)2CH(CH3)2         i-pentyl     1.921000e-05  4.423000e-07
# CH2C6H5                      Bz     1.793000e-05  1.651000e-06
# CH2CH2C6H5             (CH2)2Ph     1.598000e-05  3.311000e-06
# (CH2)3C6H5             (CH2)3Ph     1.526000e-05  2.108000e-06
# CH(CH3)2                   i-Pr     1.457000e-05  2.013000e-06
# cyc-C6H11            cyclohexyl     6.974000e-06  2.730000e-06
# CH2CH(CH3)2                i-Bu     5.052000e-06  1.163000e-06
# ...

# %%
n = df['acid rate (s-1)']
e = df['acid err']

#n = df['base rate (M-1s-1)']
#e = df['base err']

a = unp.uarray(n, e)  # Create an array of uncertainties
a = unp.log10(a/a[1])

for i in a:
#    print(f"{i.n:.3e} ± {unp.std_devs(i):.3e}")
    print(f"{i:.3f}")
# Out:
# 1.240+/-0.108
# 0.000+/-0
# -0.190+/-0.078
# -0.070+/-0.063
# -0.360+/-0.063
# -0.390+/-0.078
# -0.400+/-0.092
# -0.350+/-0.061
# -0.380+/-0.072
# -0.430+/-0.108
# -0.450+/-0.085
# -0.470+/-0.085
# -0.790+/-0.180
# -0.930+/-0.117
# -0.980+/-0.078
# -1.130+/-0.171
# -1.190+/-0.092
# -1.500+/-0.117
# -1.540+/-0.063
# -1.760+/-0.162
# -1.980+/-0.286
# -1.990+/-nan
# -2.060+/-nan
# -2.550+/-0.100

# %%
unp.log10(un.ufloat(100,10))
# Out:
# array(2.0+/-0.043429448190325175, dtype=object)
